# %%
import pandas as pd

# %%
import pandas as pd
import glob
df = pd.read_csv("ap_bus_details.csv")
df = pd.read_csv("assam_bus_details.csv")
df = pd.read_csv("chandigarh_bus_details.csv")
df = pd.read_csv("Haryana_bus_details.csv")
df = pd.read_csv("kadamba_bus_details.csv")
df = pd.read_csv("kerala_bus_details.csv")
df = pd.read_csv("Rajasthan_bus_details.csv")
df = pd.read_csv("west bengal_bus_details.csv")
df = pd.read_csv("Telangana_bus_details.csv")
df = pd.read_csv("up_bus_details.csv")
df
# Out:
#                                  Route_Name  \
# 0         Delhi to Bareilly (Uttar Pradesh)
# 1         Delhi to Bareilly (Uttar Pradesh)
# 2         Delhi to Bareilly (Uttar Pradesh)
# 3         Delhi to Bareilly (Uttar Pradesh)
# 4         Delhi to Bareilly (Uttar Pradesh)
# ...                                     ...
# 2303  Shahjahanpur (Uttar Pradesh) to Delhi
# 2304  Shahjahanpur (Uttar Pradesh) to Delhi
# 2305  Shahjahanpur (Uttar Pradesh) to Delhi
# 2306  Shahjahanpur (Uttar Pradesh) to Delhi
# 2307  Shahjahanpur (Uttar Pradesh) to Delhi
#
#                                              Route_Link            Bus_Name  \
# 0     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - RKD0134
# 1     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - STD0161
# 2     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - GRH0229
# 3     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - RKD0129
# ...

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\ap_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\kadamba_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\kerala_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\rajasthan_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\Telangana_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\up_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\west bengal_bus_details.csv")
df = pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\chandigarh_bus_details.csv")
df = pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\assam_bus_details.csv")
df= pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\bus_routes.csv")
df
# Out:
#                                   Route_Name  \
# 0     Chittoor (Andhra Pradesh) to Bangalore
# 1     Chittoor (Andhra Pradesh) to Bangalore
# 2     Chittoor (Andhra Pradesh) to Bangalore
# 3     Chittoor (Andhra Pradesh) to Bangalore
# 4     Chittoor (Andhra Pradesh) to Bangalore
# ...                                      ...
# 8269   Shahjahanpur (Uttar Pradesh) to Delhi
# 8270   Shahjahanpur (Uttar Pradesh) to Delhi
# 8271   Shahjahanpur (Uttar Pradesh) to Delhi
# 8272   Shahjahanpur (Uttar Pradesh) to Delhi
# 8273   Shahjahanpur (Uttar Pradesh) to Delhi
#
#                                              Route_Link            Bus_Name  \
# 0     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 5118
# 1     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 9035
# 2     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 9057
# 3     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 9129
# ...

# %%
df.isnull().sum()
# Out:
# Route_Name           0
# Route_Link           0
# Bus_Name             0
# Bus_Type             0
# Departing_Time       0
# Duration             0
# Reaching_Time        0
# Star_Rating          0
# Price                0
# Seat_Availability    0
# dtype: int64

# %%
df.dropna(inplace=True)  # Remove rows with missing values
df.dropna(axis=1, inplace=True)  # Remove columns with missing values
df
# Out:
#                                   Route_Name  \
# 0     Chittoor (Andhra Pradesh) to Bangalore
# 1     Chittoor (Andhra Pradesh) to Bangalore
# 2     Chittoor (Andhra Pradesh) to Bangalore
# 3     Chittoor (Andhra Pradesh) to Bangalore
# 4     Chittoor (Andhra Pradesh) to Bangalore
# ...                                      ...
# 8269   Shahjahanpur (Uttar Pradesh) to Delhi
# 8270   Shahjahanpur (Uttar Pradesh) to Delhi
# 8271   Shahjahanpur (Uttar Pradesh) to Delhi
# 8272   Shahjahanpur (Uttar Pradesh) to Delhi
# 8273   Shahjahanpur (Uttar Pradesh) to Delhi
#
#                                              Route_Link            Bus_Name  \
# 0     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 5118
# 1     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 9035
# 2     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 9057
# 3     https://www.redbus.in/bus-tickets/chittoor-and...       APSRTC - 9129
# ...

# %%
import pandas as pd

# List of file paths
file_paths = [
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\ap_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\kadamba_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\kerala_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\rajasthan_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\Telangana_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\up_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\west bengal_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\chandigarh_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\assam_bus_details.csv",
    r"C:\Users\DELL\OneDrive\문서\guvi_projects\bus_routes.csv",
]

# Read each file into a DataFrame and store them in a list
dataframes = [pd.read_csv(file) for file in file_paths]

# Concatenate all DataFrames in the list
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_df.to_csv("bus_routes.csv", index=False)

print("Files combined and saved to 'bus_routes.csv'")


df
# Out:
# Files combined and saved to 'bus_routes.csv'
#                                          0
# 0  C:\Users\DELL\OneDrive\문서\guvi_projects

# %%
# List of CSV file paths
csv_files = ["ap_bus_details.csv", "assam_bus_details.csv", "chandigarh_bus_details.csv", "Haryana_bus_details.csv", "kadamba_bus_details.csv", "kerala_bus_details.csv","Rajasthan_bus_details.csv", "west bengal_bus_details.csv", "Telangana_bus_details.csv", "up_bus_details.csv"]

# %%
# Read each CSV file into a DataFrame and store it in a list
df = [r"C:\Users\DELL\OneDrive\문서\guvi_projects"]
df
# Out:
# ['C:\\Users\\DELL\\OneDrive\\문서\\guvi_projects']

# %%
df=pd.DataFrame([r"C:\Users\DELL\OneDrive\문서\guvi_projects"])
df
# Out:
#                                          0
# 0  C:\Users\DELL\OneDrive\문서\guvi_projects

# %%
import pandas as pd

# Assuming your dataframe is named 'df'
df['Price'] = df['Price'].replace({'INR': '', ',': ''}, regex=True)  # Remove 'INR' and commas
df['Price'] = df['Price'].astype(float)  # Convert the cleaned column to float

# Now df['Price'] will have decimal values
df
# Out:
#                                  Route_Name  \
# 0         Delhi to Bareilly (Uttar Pradesh)
# 1         Delhi to Bareilly (Uttar Pradesh)
# 2         Delhi to Bareilly (Uttar Pradesh)
# 3         Delhi to Bareilly (Uttar Pradesh)
# 4         Delhi to Bareilly (Uttar Pradesh)
# ...                                     ...
# 2303  Shahjahanpur (Uttar Pradesh) to Delhi
# 2304  Shahjahanpur (Uttar Pradesh) to Delhi
# 2305  Shahjahanpur (Uttar Pradesh) to Delhi
# 2306  Shahjahanpur (Uttar Pradesh) to Delhi
# 2307  Shahjahanpur (Uttar Pradesh) to Delhi
#
#                                              Route_Link            Bus_Name  \
# 0     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - RKD0134
# 1     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - STD0161
# 2     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - GRH0229
# 3     https://www.redbus.in/bus-tickets/delhi-to-bar...    UPSRTC - RKD0129
# ...

# %%
#extract the digits(0-9)
df['Seat_Availability'] = df['Seat_Availability'].str.extract('(\d+)')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_260\312744048.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['Seat_Availability'] = df['Seat_Availability'].str.extract('(\d+)')
