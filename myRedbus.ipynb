# %%
from mysql import connector
myconnection =connector.connect(
    host="localhost",
    user="root",
    password="123456789",
    database ="Redbus"
)
cursor = myconnection.cursor()
cursor

# %%
import pandas as pd
(r"C:/Users/DELL/OneDrivedf = pd.read_csv/문서/guvi_projects/bus_routes.csv")
# Out:
# 'C:/Users/DELL/OneDrivedf = pd.read_csv/문서/guvi_projects/bus_routes.csv'

# %%
import pandas as pd
df
# Out:
#                          Route_Name  \
# 0    Digha to Barasat (West Bengal)
# 1    Digha to Barasat (West Bengal)
# 2    Digha to Barasat (West Bengal)
# 3    Digha to Barasat (West Bengal)
# 4    Digha to Barasat (West Bengal)
# ..                              ...
# 420               Kolkata to Haldia
# 421               Kolkata to Haldia
# 422               Kolkata to Haldia
# 423               Kolkata to Haldia
# 424               Kolkata to Haldia
#
#                                             Route_Link  \
# 0    https://www.redbus.in/bus-tickets/digha-to-bar...
# 1    https://www.redbus.in/bus-tickets/digha-to-bar...
# 2    https://www.redbus.in/bus-tickets/digha-to-bar...
# 3    https://www.redbus.in/bus-tickets/digha-to-bar...
# 4    https://www.redbus.in/bus-tickets/digha-to-bar...
# ..                                                 ...
# 420  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 421  https://www.redbus.in/bus-tickets/kolkata-to-h...
# ...

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\ap_bus_details.csv")
df
# Out:
#                                   Route_Name  \
# 0     Chittoor (Andhra Pradesh) to Bangalore
# 1     Chittoor (Andhra Pradesh) to Bangalore
# 2     Chittoor (Andhra Pradesh) to Bangalore
# 3     Chittoor (Andhra Pradesh) to Bangalore
# 4     Chittoor (Andhra Pradesh) to Bangalore
# ...                                      ...
# 1549                 Hyderabad to Markapuram
# 1550                 Hyderabad to Markapuram
# 1551                 Hyderabad to Markapuram
# 1552                 Hyderabad to Markapuram
# 1553                 Hyderabad to Markapuram
#
#                                              Route_Link  \
# 0     https://www.redbus.in/bus-tickets/chittoor-and...
# 1     https://www.redbus.in/bus-tickets/chittoor-and...
# 2     https://www.redbus.in/bus-tickets/chittoor-and...
# 3     https://www.redbus.in/bus-tickets/chittoor-and...
# 4     https://www.redbus.in/bus-tickets/chittoor-and...
# ...                                                 ...
# ...

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\assam_bus_details.csv")
df
# Out:
#               Route_Name                                         Route_Link  \
# 0       Delhi to Patiala  https://www.redbus.in/bus-tickets/delhi-to-pat...
# 1       Delhi to Patiala  https://www.redbus.in/bus-tickets/delhi-to-pat...
# 2       Delhi to Patiala  https://www.redbus.in/bus-tickets/delhi-to-pat...
# 3       Delhi to Patiala  https://www.redbus.in/bus-tickets/delhi-to-pat...
# 4       Delhi to Patiala  https://www.redbus.in/bus-tickets/delhi-to-pat...
# ..                   ...                                                ...
# 889  Patiala to Amritsar  https://www.redbus.in/bus-tickets/patiala-to-a...
# 890  Patiala to Amritsar  https://www.redbus.in/bus-tickets/patiala-to-a...
# 891  Patiala to Amritsar  https://www.redbus.in/bus-tickets/patiala-to-a...
# 892  Patiala to Amritsar  https://www.redbus.in/bus-tickets/patiala-to-a...
# 893  Patiala to Amritsar  https://www.redbus.in/bus-tickets/patiala-to-a...
#
#                                  Bus_Name  \
# ...

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\chandigarh_bus_details.csv")
df
# Out:
#                  Route_Name  \
# 0       Delhi to Chandigarh
# 1       Delhi to Chandigarh
# 2       Delhi to Chandigarh
# 3       Delhi to Chandigarh
# 4       Delhi to Chandigarh
# ..                      ...
# 481  Chandigarh to Haridwar
# 482  Chandigarh to Haridwar
# 483  Chandigarh to Haridwar
# 484  Chandigarh to Haridwar
# 485  Chandigarh to Haridwar
#
#                                             Route_Link  \
# 0    https://www.redbus.in/bus-tickets/delhi-to-cha...
# 1    https://www.redbus.in/bus-tickets/delhi-to-cha...
# 2    https://www.redbus.in/bus-tickets/delhi-to-cha...
# 3    https://www.redbus.in/bus-tickets/delhi-to-cha...
# 4    https://www.redbus.in/bus-tickets/delhi-to-cha...
# ..                                                 ...
# 481  https://www.redbus.in/bus-tickets/chandigarh-t...
# 482  https://www.redbus.in/bus-tickets/chandigarh-t...
# 483  https://www.redbus.in/bus-tickets/chandigarh-t...
# 484  https://www.redbus.in/bus-tickets/chandigarh-t...
# ...

# %%
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\Haryana_bus_details.csv")
df
# Out:
#                             Route_Name  \
# 0                      Delhi to Shimla
# 1                      Delhi to Shimla
# 2                      Delhi to Shimla
# 3                      Delhi to Shimla
# 4                      Delhi to Shimla
# ..                                 ...
# 933  Baddi (Himachal Pradesh) to Delhi
# 934  Baddi (Himachal Pradesh) to Delhi
# 935  Baddi (Himachal Pradesh) to Delhi
# 936  Baddi (Himachal Pradesh) to Delhi
# 937  Baddi (Himachal Pradesh) to Delhi
#
#                                             Route_Link        Bus_Name  \
# 0    https://www.redbus.in/bus-tickets/delhi-to-shimla  HRTC - 2100720
# 1    https://www.redbus.in/bus-tickets/delhi-to-shimla        HRTC - 6
# 2    https://www.redbus.in/bus-tickets/delhi-to-shimla      HRTC - 592
# 3    https://www.redbus.in/bus-tickets/delhi-to-shimla      HRTC - 129
# 4    https://www.redbus.in/bus-tickets/delhi-to-shimla        HRTC - 7
# ...

# %%
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\kadamba_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\kerala_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\rajasthan_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\Telangana_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\up_bus_details.csv")
df =pd.read_csv(r"C:\Users\DELL\OneDrive\문서\guvi_projects\west bengal_bus_details.csv")
df
# Out:
#                          Route_Name  \
# 0    Digha to Barasat (West Bengal)
# 1    Digha to Barasat (West Bengal)
# 2    Digha to Barasat (West Bengal)
# 3    Digha to Barasat (West Bengal)
# 4    Digha to Barasat (West Bengal)
# ..                              ...
# 420               Kolkata to Haldia
# 421               Kolkata to Haldia
# 422               Kolkata to Haldia
# 423               Kolkata to Haldia
# 424               Kolkata to Haldia
#
#                                             Route_Link  \
# 0    https://www.redbus.in/bus-tickets/digha-to-bar...
# 1    https://www.redbus.in/bus-tickets/digha-to-bar...
# 2    https://www.redbus.in/bus-tickets/digha-to-bar...
# 3    https://www.redbus.in/bus-tickets/digha-to-bar...
# 4    https://www.redbus.in/bus-tickets/digha-to-bar...
# ..                                                 ...
# 420  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 421  https://www.redbus.in/bus-tickets/kolkata-to-h...
# ...

# %%
df = df.dropna() #drop null values
a = ",".join(f"{i} {j}"
for i,j in zip(df.columns,df.dtypes)).replace("float64","float").replace("object","text").replace("int64","int") #replace dtypes from pandas to mysql
table_name = "Redbus"
myconnection.cursor().execute(f"create table {table_name} ({a})")
for i in range(len(df)):
    myconnection.cursor().execute(f"insert into {table_name} values {tuple(df.iloc[i])}")
    myconnection.commit()
